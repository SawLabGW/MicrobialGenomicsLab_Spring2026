# %% [markdown]
# ## Week 11

# %% [markdown]
# ### Agenda for (03/23/2026)

# %% [markdown]
# - Lecture (Microbial genome evolution and comparative genomics)
# - Lab exercises
#   - Comparative genomic analyses:
#     - fastANI and genoPlotR
#   - Pangenomic analyses:
#     - Anvi'o
