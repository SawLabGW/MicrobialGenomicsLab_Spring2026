# %% [markdown]
# ## Week 13

# %% [markdown]
# ### Agenda for 04/06/2026

# %% [markdown]
# - Learning to use citation managers with Word and Google doc
# - Lab exercises
#   - visualization techniques/tools in Python and R
# - Work on group projects
