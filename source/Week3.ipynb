# %% [markdown]
# # Week 3

# %% [markdown]
# ## Plans for (01/26/2026)
#
#   - Install some necessary tools using `conda`:
#     - sra-tools
#     - ffq
#     - fastqc
#     - bbmap
#   - Group activity to download and test tools with sample datasets
#
#   - Assignments:
#     - Assignment 1 (due Feb 2)
#     - Reading assignments
